# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (5, 6)
plt.xkcd()

# %matplotlib inline

# %%
df = pd.read_csv("log_j0331.txt") #, index_col=0
df.rename({"12/12/2014 08:22:50":"Data", "20.65":"T_Cam", "22.00":"T7",  "35":"T2", "21.25":"T3",   "21.75.13":"PYRO","21.75.14":"NR"}, axis="columns", inplace=True)

# %%
#df.rename(index=str, columns=["A", "B"])

# %%
df
#df.head()
# Out:
#                     Data  T_Cam  T2     T3  21.75  21.75.1  21.75.2     T7  \
# 0    12/12/2014 08:23:50  20.80  35  21.75  22.00    22.00    22.00  22.25
# 1    12/12/2014 08:24:50  20.95  35  23.25  23.50    23.75    23.50  23.75
# 2    12/12/2014 08:25:50  21.24  35  31.00  30.75    31.25    31.00  31.50
# 3    12/12/2014 08:26:50  21.53  35  36.75  36.75    37.00    36.75  37.50
# 4    12/12/2014 08:27:50  21.83  35  40.50  40.50    41.00    40.50  41.50
# 5    12/12/2014 08:28:50  22.27  35  43.25  43.25    43.50    43.00  44.25
# 6    12/12/2014 08:29:50  22.85  35  45.00  45.25    45.50    45.00  46.25
# 7    12/12/2014 08:30:50  24.02  35  46.50  46.75    46.75    46.25  47.75
# 8    12/12/2014 08:31:50  24.61  35  47.50  47.75    47.75    47.50  49.00
# 9    12/12/2014 08:32:50  24.90   0  48.25  48.75    48.50    48.25  49.75
# 10   12/12/2014 08:33:50  25.49  35  49.00  49.50    49.25    49.00  50.50
# ...

# %%
df.columns
# Out:
# Index(['Data', 'T_Cam', 'T2', 'T3', '21.75', '21.75.1', '21.75.2', 'T7',
#        '21.75.3', '21.75.4', '21.75.5', '21.75.6', '21.75.7', '22.00.1',
#        '22.00.2', '22.00.3', '22.00.4', '22.00.5', '22.25', '22.25.1',
#        '22.00.6', '22.25.2', '22.00.7', '22.00.8', '22.00.9', '22.25.3',
#        '22.75', '22.25.4', '22.00.10', '22.00.11', '22.00.12', '21.75.8',
#        '21.75.9', '21.75.10', '21.75.11', '21.75.12', 'PYRO', 'NR'],
#       dtype='object')

# %%
import datetime

df.as_matrix()
# Out:
# array([['12/12/2014 08:23:50', 20.8, 35, ..., 22.0, 22.0, 22.0],
#        ['12/12/2014 08:24:50', 20.95, 35, ..., 23.25, 23.5, 23.5],
#        ['12/12/2014 08:25:50', 21.24, 35, ..., 30.25, 31.25, 30.5],
#        ...,
#        ['12/12/2014 12:10:50', 42.92, 35, ..., 57.5, 58.5, 57.25],
#        ['12/12/2014 12:11:50', 42.92, 34, ..., 57.75, 58.5, 57.25],
#        ['12/12/2014 12:12:50', 43.07, 35, ..., 57.75, 58.75, 57.25]],
#       dtype=object)

# %%
#df.dtypes

# %%
#plt.rcParams["figure.figsize"] = (10, 6)
df[["T_Cam", "T2", "T3", "PYRO", "NR"]].plot()
#df[4:7].plot()

# %%
df.describe()
# Out:
#             T_Cam          T2          T3       21.75     21.75.1     21.75.2  \
# count  230.000000  230.000000  230.000000  230.000000  230.000000  230.000000
# mean    41.426000   33.739130   56.503261   58.275000   57.768478   57.269565
# std      6.070478    5.851267    4.952255    5.314372    5.173036    5.100266
# min     20.800000    0.000000   21.750000   22.000000   22.000000   22.000000
# 25%     40.615000   35.000000   56.500000   58.250000   57.562500   57.250000
# 50%     43.510000   35.000000   57.750000   59.500000   59.000000   58.500000
# 75%     44.970000   35.000000   58.750000   60.500000   60.000000   59.500000
# max     47.610000   44.000000   60.500000   62.750000   62.000000   61.500000
#
#                T7     21.75.3     21.75.4     21.75.5     ...        22.00.10  \
# count  230.000000  230.000000  230.000000  230.000000     ...      230.000000
# mean    58.913043   57.568478   56.803261   57.356522     ...       58.320652
# ...

# %%
#np.std(df.as_matrix(df.iloc[0:2][df.columns[3:5]]))
#seaborn.heatmap(df.iloc[0:2][df.columns[0:5]])

# %%
df.iloc[0:2][df.columns[2:10]].plot()

# %%
import seaborn
